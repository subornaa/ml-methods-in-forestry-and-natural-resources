# %% [markdown]
# ### 3. Discussions - Case studies
#
# #### Estimating merchantable stem volume
# **Discussion: Which Machine Learning techniques could help build models predicting volume? How would you incorporate the described datasets?**
#
# * DBH and height are predictor variables, while indirectly measured volume is the estimated variable.
# * Linear or nonlinear least-squares regression depending. Nigh (2016) used nonlinear least-quares regression. These methods are highly interpretable as the equation can even be used in Excel
# * Regression methods using bagging like Random Forest Regressions are not suitable due to the low number of predictor variables.
#
# #### Characterize the visitors of protected areas
# **Discussion: Which Machine Learning techniques could help with visitor characterization using the described survey dataset and "benefit segmentation" approach?**
#
# * Are questionair attributes correlated?
# * Unsupervised clustering methods could help group the observations based on the attributes from the questionaire. A common method is K-means.
# * The "optimal" number of K clusters should be determined.
# * Questionaire attributes should be evaluated by cluster. Boxplots can be used for visualization and something like an ANOVA test can be used to statistically compare clusters.
# * Develop describtions of visitors by cluster.
# * Subjective
#
# #### Predicting land cover type
# **Discussion: Which Machine Learning techniques could help map the described land cover classes accross Canada anually? What datasets could be used?**
#
# * Supervised machine learning
# * Classification
# * Examples: Logistic regression and random forest classification.
# * Potential predictors: Metrics based on surface reflection from Landsat, digital elevation model, climate maps etc...
# * Training data: existing land cover map from 2000 and/or extensive field sampling dataset
